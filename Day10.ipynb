# %%
import pandas as pd
# Out:
# C:\Users\uSER\AppData\Local\Temp\ipykernel_8960\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\uSER\Downloads\california_housing_test.csv")

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
x = df[['median_income']]
y = df[['median_house_value']]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
r_sq = model.score(x, y)   #how much correct your answer is?
print(r_sq)
# Out:
# 0.4525187692076116

# %%
model.coef_    #how much sensitive data is?
# Out:
# array([[41032.39913763]])

# %%
model.intercept_    #
# Out:
# array([49624.77887696])

# %% [markdown]
# ### Linear Regression in python
# #### 1. Import package in python

# %%
import numpy as np   # for numerical operation
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### 2. Data

# %%
x = np.array([5,15,25,35,45,55]).reshape((-1,1))
y = np.array([5,20,14,32,22,38])

# %% [markdown]
# #### 3. Create a model

# %%
model = LinearRegression()

# %% [markdown]
# #### 4. fit model

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %% [markdown]
# #### 5. Score

# %%
model.score(x,y)
# Out:
# 0.7158756137479542

# %% [markdown]
# #### 6. Intercept

# %%
model.intercept_
# Out:
# 5.633333333333329

# %% [markdown]
# #### 7. Coefficient

# %%
model.coef_
# Out:
# array([0.54])

# %%
import matplotlib.pyplot as plt   # for plotting

# %%
plt.scatter(x, y, color="Blue")    #Plots scatter dots
plt.xticks(())    #removes numbering on X Axis
plt.yticks(())    #removes numbering on Y Axis
plt.show()
plt.plot(x,y, color="Green", linewidth=3)   #Plots line corresponding to scattered dots

# %%
model.predict(x)
# Out:
# array([ 8.33333333, 13.73333333, 19.13333333, 24.53333333, 29.93333333,
#        35.33333333])

# %% [markdown]
# 1. Before using linear regression between two variable, we are supposed to check correlation between them
# 2. Linear regression can only be applied on continuous numerical datatype

# %%
df.corr()    #also known as KPCC Karl Pearson Coefficient of correlation
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925017           -0.064203     0.049865
# latitude            -0.925017  1.000000           -0.025143    -0.039632
# housing_median_age  -0.064203 -0.025143            1.000000    -0.367850
# total_rooms          0.049865 -0.039632           -0.367850     1.000000
# total_bedrooms       0.070869 -0.068245           -0.323154     0.937749
# population           0.111572 -0.117318           -0.299888     0.838867
# households           0.051062 -0.068296           -0.305171     0.914116
# median_income       -0.018701 -0.072363           -0.144315     0.221249
# median_house_value  -0.050662 -0.138428            0.091409     0.160427
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.070869    0.111572    0.051062      -0.018701
# latitude                 -0.068245   -0.117318   -0.068296      -0.072363
# ...

# %%
import seaborn as sns
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
diabetes_X, diabetes_Y = datasets.load_diabetes(return_X_y=True)

# %%
print(diabetes_X.shape)
print(diabetes_Y.shape)
# Out:
# (442, 10)
# (442,)

# %% [markdown]
# #### Use on one feature(Column) in X

# %%
diabetes_X = diabetes_X[:, np.newaxis, 2]

# %% [markdown]
# #### Split the data into training and testing sets

# %%
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# %% [markdown]
# #### Split the Targets into training and testing sets

# %%
diabetes_Y_train = diabetes_Y[:-20]
diabetes_Y_test = diabetes_Y[-20:]

# %%
regr = linear_model.LinearRegression()

# %%
regr.fit(diabetes_X_train, diabetes_Y_train)
# Out:
# LinearRegression()

# %%
diabetes_y_pred = regr.predict(diabetes_X_test)

# %%
print("Coefficients:\n", regr.coef_)
print("Mean Square error: %.2f" %mean_squared_error(diabetes_Y_test, diabetes_y_pred))
print("Coefficient of determination: %.2f" %r2_score(diabetes_Y_test, diabetes_y_pred))
# Out:
# Coefficients:
#  [938.23786125]
# Mean Square error: 2548.07
# Coefficient of determination: 0.47
